# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ohms\\Desktop\\SWC-ANU_2016'

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.head
# Out:
# <bound method NDFrame.head of        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df['day']
# Out:
# 0        16
# 1        16
# 2        16
# 3        16
# 4        16
# 5        16
# 6        16
# 7        16
# 8        16
# 9        16
# 10       16
# 11       16
# 12       16
# 13       16
# 14       16
# 15       16
# 16       16
# 17       16
# 18       16
# 19       17
# 20       17
# 21       17
# 22       17
# 23       17
# 24       17
# 25       17
# 26       17
# 27       17
# 28       17
# 29       17
#          ..
# 35519    31
# 35520    31
# 35521    31
# 35522    31
# 35523    31
# 35524    31
# 35525    31
# 35526    31
# 35527    31
# 35528    31
# 35529    31
# 35530    31
# 35531    31
# 35532    31
# 35533    31
# 35534    31
# 35535    31
# 35536    31
# 35537    31
# 35538    31
# 35539    31
# 35540    31
# 35541    31
# 35542    31
# 35543    31
# 35544    31
# 35545    31
# 35546    31
# 35547    31
# 35548    31
# Name: day, dtype: int64

# %%
pd.unique(surveys_df['day'])
# Out:
# array([16, 17, 18, 19, 20, 21, 11, 12, 13, 14, 10,  8,  9,  6,  7,  4,  5,
#         3,  2, 28, 29, 24, 25, 31, 30, 26, 22, 23, 15, 27,  1], dtype=int64)

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
pd.unique(surveys_df['plot_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24], dtype=int64)

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].count()
# Out:
# 32283

# %%
sorted = surveys_df.groupby('sex')

# %%
sorted.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
sorted['weight'].mean()
# Out:
# sex
# F    42.170555
# M    42.995379
# Name: weight, dtype: float64

# %%
sorted2 = surveys_df.groupby(['sex', 'plot_id'])

# %%
sorted2['weight'].mean()
# Out:
# sex  plot_id
# F    1          46.311138
#      2          52.561845
#      3          31.215349
#      4          46.818824
#      5          40.974806
#      6          36.352288
#      7          20.006135
#      8          45.623011
#      9          53.618469
#      10         17.094203
#      11         43.515075
#      12         49.831731
#      13         40.524590
#      14         47.355491
#      15         26.670236
#      16         25.810427
#      17         48.176201
#      18         36.963514
#      19         21.978599
#      20         52.624406
#      21         25.974832
#      22         53.647059
#      23         20.564417
#      24         47.914405
# M    1          55.950560
#      2          51.391382
#      3          34.163241
#      4          48.888119
#      5          40.708551
#      6          36.867388
#      7          21.194719
#      8          49.641372
#      9          49.519309
#      10         19.971223
#      11         43.366197
# ...

# %%
sorted.describe()
# Out:
#                     day  hindfoot_length         month       plot_id  \
# sex
# F   count  15690.000000     14894.000000  15690.000000  15690.000000
#     mean      16.007138        28.836780      6.583047     11.440854
#     std        8.271144         9.463789      3.367350      6.870684
#     min        1.000000         7.000000      1.000000      1.000000
#     25%        9.000000        21.000000      4.000000      5.000000
#     50%       16.000000        27.000000      7.000000     12.000000
#     75%       23.000000        36.000000     10.000000     17.000000
#     max       31.000000        64.000000     12.000000     24.000000
# M   count  17348.000000     16476.000000  17348.000000  17348.000000
#     mean      16.184286        29.709578      6.392668     11.098282
#     std        8.199274         9.629246      3.420806      6.728713
#     min        1.000000         2.000000      1.000000      1.000000
# ...

# %%
species_counts = surveys_df.groupby('species_id').count()

# %%
surveys_df.groupby('sex').count()
# Out:
#      record_id  month    day   year  plot_id  species_id  hindfoot_length  \
# sex
# F        15690  15690  15690  15690    15690       15690            14894
# M        17348  17348  17348  17348    17348       17348            16476
#
#      weight
# sex
# F     15303
# M     16879

# %%
surveys_df['weight']*5
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#          ...
# 35519    180.0
# 35520    240.0
# 35521    225.0
# 35522    220.0
# 35523    135.0
# 35524    130.0
# 35525    120.0
# 35526    215.0
# 35527      NaN
# 35528    125.0
# 35529      NaN
# 35530      NaN
# 35531    215.0
# 35532    240.0
# 35533    280.0
# 35534    265.0
# 35535    210.0
# 35536    230.0
# 35537    155.0
# 35538    340.0
# 35539    115.0
# 35540    155.0
# 35541    145.0
# 35542    170.0
# 35543      NaN
# 35544      NaN
# 35545      NaN
# ...

# %%
surveys_df['weight2'] = surveys_df['weight']*5

# %%
surveys_df.describe()
# Out:
#           record_id         month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000  35549.000000
# mean   17775.000000      6.474022     16.105966   1990.475231     11.397001
# std    10262.256696      3.396583      8.256691      7.493355      6.799406
# min        1.000000      1.000000      1.000000   1977.000000      1.000000
# 25%     8888.000000      4.000000      9.000000   1984.000000      5.000000
# 50%    17775.000000      6.000000     16.000000   1990.000000     11.000000
# 75%    26662.000000      9.000000     23.000000   1997.000000     17.000000
# max    35549.000000     12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight       weight2
# count     31438.000000  32283.000000  32283.000000
# mean         29.287932     42.672428    213.362141
# std           9.564759     36.631259    183.156297
# min           2.000000      4.000000     20.000000
# ...

# %%
# %matplotlib inline

# %%
species_counts = surveys_df.groupby('species_id').count()
species_counts.plot(kind='bar')

# %%
total_count = surveys_df['record_id'].groupby(surveys_df['plot_id']).nunique()

# %%
total_count.plot(kind='bar')

# %%
surveys_df_1982 = surveys_df['year' == 1982]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-56a0920d8dfe> in <module>()
# ----> 1 surveys_df_1982 = surveys_df['year' == 1982]
#
# NameError: name 'surveys_df' is not defined

# %%
surveys_df[(surveys_df.year >= 1980)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-13649c383cc2> in <module>()
# ----> 1 surveys_df[(surveys_df.year >= 1980)]
#
# NameError: name 'surveys_df' is not defined

# %%
import pandas as pd
surveys_df = pd.read_csv('surveys.csv')

# %%
surveys_df[(surveys_df.year >= 1980)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# 2275        2276      1   15  1980       11         DS    M             47.0
# 2276        2277      1   15  1980        8         PF    M             15.0
# 2277        2278      1   15  1980        9         OT    M             21.0
# 2278        2279      1   15  1980       11         DM    F             36.0
# 2279        2280      1   15  1980       21         OT    F             20.0
# 2280        2281      1   15  1980       11         OL    M             20.0
# ...

# %%
surveys_1982 = surveys_df[(surveys_df.year == 1982)]

# %%
surveys_1982_grouped_by_sex = surveys_1982.groupby('sex')

# %%
surveys_1982_grouped_by_sex

# %%
surveys_df[(surveys_df.year == 1982)]
# Out:
#       record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5157       5158      1    1  1982        1         DO   F             37.0
# 5158       5159      1    1  1982        5         DM   F             34.0
# 5159       5160      1    1  1982        3         RM   F             16.0
# 5160       5161      1    1  1982        5         NL   F             33.0
# 5161       5162      1    1  1982        3         RM   F             17.0
# 5162       5163      1    1  1982        3         NL   F             34.0
# 5163       5164      1    1  1982        2         DS   F             49.0
# 5164       5165      1    1  1982        3         PF   M             15.0
# 5165       5166      1    1  1982        4         DM   M             36.0
# 5166       5167      1    1  1982        2         DM   M             35.0
# 5167       5168      1    1  1982        4         DS   M             52.0
# ...

# %%
res = surveys_df[(surveys_df.year == 1982)].groupby('sex').mean()

# %%
res['weight'][0]
# Out:
# 55.440197287299632

# %%
surveys_df[(surveys_df.year == 1982)].groupby('sex').mean()
# Out:
#        record_id     month        day    year    plot_id  hindfoot_length  \
# sex
# F    6169.795869  6.408262  23.063183  1982.0  11.674362        31.960294
# M    6137.953262  6.230769  23.206426  1982.0  11.913340        31.668197
#
#         weight
# sex
# F    55.440197
# M    52.464956

# %%
res['sex'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ohms\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4027)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3891)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12408)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12359)()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e96aee5548e1> in <module>()
# ----> 1 res['sex'][0]
#
# ...
